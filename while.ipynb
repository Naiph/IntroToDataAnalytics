# %%
while False:
    print(asd)

# %%
while True:
    print('sf')
# Out:
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# sf
# ...

# %%
x=2

# %%
x
# Out:
# 2

# %%
counter=0
while counter<8:
    print('sdsd')
    counter=counter+1
print('sdfsdsfaasfasf')
# Out:
# sdsd
# sdsd
# sdsd
# sdsd
# sdsd
# sdsd
# sdsd
# sdsd
# sdfsdsfaasfasf
